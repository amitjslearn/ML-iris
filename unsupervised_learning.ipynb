# %%
import numpy as np
import pandas as pd
#import seaborn as sns
import matplotlib.pyplot as plt

#plot inline
# %matplotlib inline

# %%
#reading in th ecsv file
PATH= '/home/amit/Desktop/ML_workshop/marketing_data.xlsx'
df= pd.read_excel(PATH)

# %%
df.head() # or- df
# Out:
#            ID State  Region  Division  Group_Name  MSA_Population_Size  \
# 0  10259059.0    AL     3.0       6.0         1.0                  1.0
# 1  10261004.0    AL     3.0       6.0         6.0                  3.0
# 2  10263002.0    TN     3.0       6.0         1.0                  1.0
# 3  10265022.0    AL     3.0       6.0         1.0                  1.0
# 4         NaN   NaN     NaN       NaN         NaN                  NaN
#
#    GENDER_CODE PRESUMED_DEAD_FLAG  Primary_TOP  Primary_PE    ...    TOP  PE  \
# 0          1.0                NaN         20.0        30.0    ...     20  30
# 1          1.0                NaN         20.0        30.0    ...     20  30
# 2          1.0                NaN         71.0        11.0    ...     71  11
# 3          1.0                NaN         20.0        30.0    ...     20  30
# 4          NaN                NaN          NaN         NaN    ...      0   0
#
#   SPECIAlITY  YrsPractice  Ignore1   Ignore2  Ignore3  Ignore4  Ignore5  \
# ...

# %%
df.shape
# Out:
# (77247, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77247 entries, 0 to 77246
# Data columns (total 31 columns):
# ID                          34977 non-null float64
# State                       34969 non-null object
# Region                      34973 non-null float64
# Division                    34973 non-null float64
# Group_Name                  34977 non-null float64
# MSA_Population_Size         34977 non-null float64
# GENDER_CODE                 34949 non-null float64
# PRESUMED_DEAD_FLAG          2 non-null object
# Primary_TOP                 34977 non-null float64
# Primary_PE                  34977 non-null float64
# Primary_AD                  34977 non-null object
# Secondary                   34977 non-null object
# RX_Restriction_Indicator    2128 non-null object
# customer_id                 77247 non-null int64
# ID2                         77247 non-null int64
# MyProd1_Rx                  77247 non-null float64
# ...
